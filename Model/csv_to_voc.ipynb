# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !python /content/drive/MyDrive/UAV/Model/data/csv_to_voc.py

# %%
# !cp -r /content/drive/MyDrive/UAV/Model/data/yolo_mixed/images/train/*.jpg /content/drive/MyDrive/UAV/Model/data/yolo_mixed/images/train/*.JPG /content/drive/MyDrive/UAV/Model/data/efficientnet/images/train/person/

# %%
# !cp -r /content/drive/MyDrive/UAV/Model/data/yolo_mixed/images/val/*.jpg /content/drive/MyDrive/UAV/Model/data/yolo_mixed/images/val/*.JPG /content/drive/MyDrive/UAV/Model/data/efficientnet/images/valid/person/

# %%
# !cp -r /content/drive/MyDrive/UAV/Model/data/yolo_mixed/images/val/*.jpg /content/drive/MyDrive/UAV/Model/data/efficientnet/images/test/person/

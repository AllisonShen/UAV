# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !python /content/drive/MyDrive/UAV/Model/data/csv_to_voc.py

# %%
# !cp -r /content/drive/MyDrive/UAV/Model/data/images_mixed/*.jpg /content/drive/MyDrive/UAV/Model/data/images_mixed/*.JPG /content/drive/MyDrive/UAV/Model/data/voc_mixed/

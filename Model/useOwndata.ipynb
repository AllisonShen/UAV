# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# working directory
# !find /content/drive/ -name UAV -type d > path.txt
file = open('path.txt', 'r')
Path = file.read()
Path = Path.strip()

# %%
image_path = Path + '/Model/dataset/*'

# %%
import glob
from PIL import Image

img_list = glob.glob(image_path)
images = [file for file in img_list if file.endswith(".JPG")]

print ("images: {}".format(images))
# Out:
# images: ['/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/034.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/033.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/032.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/037.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/038.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/047.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/036.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/049.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/050.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/039.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/040.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/045.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/043.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/048.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/046.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/051.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/052.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/042.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/035.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/041.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/044.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/058.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/061.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/063.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/057.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/056.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/054.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/069.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/071.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/053.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/066.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/070.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/067.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/064.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/068.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/065.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/060.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/062.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/055.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/059.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/080.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/086.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/083.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/076.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/075.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/074.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/079.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/082.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/077.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/084.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/088.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/081.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/087.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/073.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/ ...

# %%
num = 32
for image_file in images:
  image = Image.open(image_file)
  resize_image = image.resize((320, 320))
  str_num = (4 - len(str(num)))*'0'+str(num)
  resize_image.save(path+"/Model/dataset/resize_img/"+str_num+'.JPG')
  num += 1

# %%
# the annotation file needs to be change (previous one contains local info)
import xml.etree.ElementTree as ET

def changeLabel(xmlPath, newXmlPath):
  tree = ET.parse(xmlPath)  
  root = tree.getroot()

  # change path
  path = root.find('path')
  path.text = xmlPath

  tree.write(newXmlPath)

# %% [markdown]
# create anno file which maps with resized img

# %%
! pip install labelImg
# Out:
# Requirement already satisfied: labelImg in /usr/local/lib/python3.7/dist-packages (1.8.5)
# Requirement already satisfied: pyqt5 in /usr/local/lib/python3.7/dist-packages (from labelImg) (5.15.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from labelImg) (4.2.6)
# Requirement already satisfied: PyQt5-Qt5>=5.15 in /usr/local/lib/python3.7/dist-packages (from pyqt5->labelImg) (5.15.2)
# Requirement already satisfied: PyQt5-sip<13,>=12.8 in /usr/local/lib/python3.7/dist-packages (from pyqt5->labelImg) (12.9.0)

# %%
# !labelImg
# Out:
# qt.qpa.xcb: could not connect to display
# qt.qpa.plugin: Could not load the Qt platform plugin "xcb" in "" even though it was found.
# This application failed to start because no Qt platform plugin could be initialized. Reinstalling the application may fix this problem.
#
# Available platform plugins are: eglfs, linuxfb, minimal, minimalegl, offscreen, vnc, wayland-egl, wayland, wayland-xcomposite-egl, wayland-xcomposite-glx, webgl, xcb.

# %%
xml_path =  Path + '/Model/dataset/resize_img/'
print(xml_path)
# Out:
# /content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/

# %%
xml_list = glob.glob(xml_path + '*')
xml_fileList = [file for file in xml_list if file.endswith(".xml")]

print ("file: {}".format(xml_fileList))

i = 0
for xml in xml_fileList:
  changeLabel(xml_fileList[i], xml_fileList[i])
  i += 1
# Out:
# file: ['/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0091.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0057.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0203.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0066.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0062.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0139.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0165.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0060.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0079.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0232.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0109.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0090.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0239.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0052.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0137.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0115.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0121.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0081.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0198.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0077.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0215.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0106.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0193.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0182.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0096.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0131.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0130.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0050.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0228.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0213.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0129.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0056.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0278.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0049.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0221.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0235.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0248.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0256.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0225.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0059.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0172.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0168.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0161.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0171.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0208.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0177.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0141.xml' ...

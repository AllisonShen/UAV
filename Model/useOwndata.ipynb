# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# working directory
# !find /content/drive/ -name UAV -type d > path.txt
file = open('path.txt', 'r')
path = file.read()
path = path.strip()

# %%
image_path = path + '/Model/dataset/*'

# %%
import glob
from PIL import Image

img_list = glob.glob(image_path)
images = [file for file in img_list if file.endswith(".JPG")]

print ("file_list_py: {}".format(images))
# Out:
# file_list_py: ['/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/034.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/033.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/032.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/037.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/038.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/047.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/036.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/049.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/050.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/039.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/040.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/045.JPG', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/043.JPG', '/content/drive/Othercomputers/MyL
# ...

# %%
num = 32
for image_file in images:
  image = Image.open(image_file)
  resize_image = image.resize((320, 320))
  str_num = (4 - len(str(num)))*'0'+str(num)
  resize_image.save(path+"/Model/dataset/resize_img/"+str_num+'.JPG')
  num += 1

# %%
def changeLabel(xmlPath, newXmlPath, imgPath, boxes):
    tree = elemTree.parse(xmlPath)
    root = doc.getroot()

    # change path
    path = root.find('path')
    path.text = imgPath[0]

    # change bounding box
    objects = root.findall('./object')
    for i, object_ in enumerate(objects):
        bndbox = object_.find('./bndbox')
        bndbox.find('./xmin').text = str(boxes[i][0])
        bndbox.find('./ymin').text = str(boxes[i][1])
        bndbox.find('./xmax').text = str(boxes[i][2])
        bndbox.find('./ymax').text = str(boxes[i][3])
    tree.write(newXmlPath, encoding='utf8')
